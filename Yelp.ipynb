# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn

# %matplotlib inline

# %%
reviews=pd.read_csv("yelp_review.csv")

# %%
reviews.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  vkVSCC7xljjrAI4UGfnKEQ  bv2nCi5Qv5vroFiqKGopiw  AEx2SYEUJmTxVVB18LlCwA
# 1  n6QzIUObkYshz4dz2QRJTw  bv2nCi5Qv5vroFiqKGopiw  VR6GpWIda3SfvPC-lg9H3w
# 2  MV3CcKScW05u5LVfF6ok0g  bv2nCi5Qv5vroFiqKGopiw  CKC0-MOWMqoeWf6s-szl8g
# 3  IXvOzsEMYtiJI0CARmj77Q  bv2nCi5Qv5vroFiqKGopiw  ACFtxLv8pGrrxMm6EgjreA
# 4  L_9BTb55X0GDtThi6GlZ6w  bv2nCi5Qv5vroFiqKGopiw  s2I_Ni76bjJNK9yG60iD-Q
#
#    stars        date                                               text  \
# 0      5  2016-05-28  Super simple place but amazing nonetheless. It...
# 1      5  2016-05-28  Small unassuming place that changes their menu...
# 2      5  2016-05-28  Lester's is located in a beautiful neighborhoo...
# 3      4  2016-05-28  Love coming here. Yes the place always needs t...
# 4      4  2016-05-28  Had their chocolate almond croissant and it wa...
#
#    useful  funny  cool
# 0       0      0     0
# 1       0      0     0
# ...

# %%
num_revs = reviews['business_id'].value_counts()

# %%
type(num_revs)
# Out:
# pandas.core.series.Series

# %%
num_revs.size
# Out:
# 174567

# %%
business_agg=reviews.groupby('business_id').agg({'review_id':['count'],
                                'useful':['sum'],
                               'stars':['mean']})

# %%
user_agg=reviews.groupby('user_id').agg({'review_id':['count'],
                                'useful':['sum'],
                               'stars':['mean']})

# %%
user_agg['review_id'];

# %%
business_agg.sort_values([('review_id','count')],ascending = False)
# Out:
#                        review_id useful     stars
#                            count    sum      mean
# business_id
# 4JNXUYY8wbaaDmk3BPzlWw      7362   5433  4.120484
# RESDUcs7fIiihp38-d6_6g      7006  11006  3.770340
# K7lWdNUhCbcnEvI0NhGewg      5951   8087  3.697362
# cYwJA2A6I12KNkm2rtXd5g      5448   5068  3.893722
# DkYS3arLOhA8si5uUEmHOw      4870   4926  4.268994
# f4x1YBxkLrZg652xt2KR5g      4774   3518  3.903854
# 2weQS-RnoOBhb1KsHKyoSQ      4018   5684  3.632155
# KskYqH1Bi7Z_61pH6Om8pg      3965   4043  4.227995
# eoHdUeQDNgQ6WYEnP2aiRw      3911   3504  3.056252
# ujHiaprwCQ5ewziu0Vi9rw      3836   4708  3.407977
# SMPbvZLSMMb7KU76YNYMGg      3794   6223  3.513179
# 5LNZ67Yw9RD6nf4_UhXOjw      3772   7894  3.871156
# iCQpiavjjPzJ5_3gPD5Ebg      3741   5606  4.133654
# AV6weBrZFFBfRGCbcRGO4g      3623   4755  2.627933
# rcaPajgKOJC2vo_l3xa42A      3571   3885  3.992439
# El4FC8jcawUVgw_0EIcbaQ      3445   5620  2.994485
# ...

# %%
revs2 = reviews.drop(['cool','useful','funny','text','date'],1)

# %%
for i  in range(0,len(revs2)):
    
    revs2['business_id'][i] in  revs2['business_id']
# Out:
# 's2I_Ni76bjJNK9yG60iD-Q'

# %%
bus1 = revs2.loc[revs2['business_id'].isin(['4JNXUYY8wbaaDmk3BPzlWw'])]

# %%
bus1.hist('stars')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x113744390>]],
#       dtype=object)

# %%
bus2 = revs2.loc[revs2['business_id'].isin(['RESDUcs7fIiihp38-d6_6g'])]

# %%
bus2.hist('stars')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x150231d30>]],
#       dtype=object)

# %%
bus3= revs2.loc[revs2['business_id'].isin(['K7lWdNUhCbcnEvI0NhGewg'])]
same_user13 = []
rows_bus13 = set()
array_bus3 = np.array(bus3['user_id'])
for i,rows in bus1.iterrows():
    if bus1['user_id'][i] in array_bus3:
        same_user13.append(bus1['user_id'][i])
        rows_bus1.add(i)

# %%
same_user = []
rows_bus1 = set()
array_bus2 = np.array(bus2['user_id'])
for i,rows in bus1.iterrows():
    if bus1['user_id'][i] in array_bus2:
        same_user.append(bus1['user_id'][i])
        rows_bus1.add(i)

# %%
df = pd.DataFrame(columns=["user", "bus1_rat", "bus2_rat"])
for item in same_user:
    star1 = bus1.loc[bus1['user_id'].isin([item])]['stars'].iloc[0]
    star2 = bus2.loc[bus2['user_id'].isin([item])]['stars'].iloc[0]
    df = df.append({"user":item,"bus1_rat":star1,"bus2_rat":star2},ignore_index = True)

# %%
df13
# Out:
#                        user bus1_rat bus3_rat
# 0    SuyRUCI27QjQnQk7RNCu6Q        5        5
# 1    DK9eq2zjoESaXpXK7zZIUw        4        3
# 2    6YYpJ59jfFCUHkGOpu2NTA        5        4
# 3    iDjEnEvxecN1B_0P8OyaSA        2        2
# 4    V9WPHjF6jXsJRf9cba4TeA        4        4
# 5    ZwHE01vJN7Zod17adEw8Kw        4        4
# 6    O8M-LETl8rMBPwr9E8HxXg        4        3
# 7    Eobyjyz27IV8gW3mYbFxWg        3        2
# 8    RKfETgoe0wuZds8EMDBw0Q        4        4
# 9    2Yg3D3xUNNzmn-SicXZOnA        4        4
# 10   eRvPOtsjkzTjn0f__HaXKQ        3        3
# 11   BTsyCC8AmftuDQCDTqBDAw        4        4
# 12   C1K9VHWJuBInQTNBEfWqhw        5        5
# 13   iEFHhjRwycpEyv5l4jKbDQ        2        3
# 14   Hd5h-uSjhGzSmH2GwFybXA        2        5
# 15   UXAPXFo89WUeG0xm1dlF6Q        3        5
# 16   HMXi4ySve0_SNvLxwz1Vfg        3        4
# 17   CRlIhFoFQZQPw0GAU65YsQ        4        3
# 18   edZ6kTxithgtctw1crIkBA        3        3
# ...

# %%
df13 = pd.DataFrame(columns=["user", "bus1_rat", "bus3_rat"])
for item in same_user13:
    star1 = bus1.loc[bus1['user_id'].isin([item])]['stars'].iloc[0]
    star3 = bus3.loc[bus3['user_id'].isin([item])]['stars'].iloc[0]
    df13 = df13.append({"user":item,"bus1_rat":star1,"bus3_rat":star3},ignore_index = True)

# %%
df
# Out:
#                        user bus1_rat bus2_rat
# 0    JXHrhT72U6sZJQSkFfNzjw        3        5
# 1    XrdEvB5ZuMwZN9J4aI55FA        5        3
# 2    6YYpJ59jfFCUHkGOpu2NTA        5        5
# 3    RKfETgoe0wuZds8EMDBw0Q        4        4
# 4    2Yg3D3xUNNzmn-SicXZOnA        4        5
# 5    C1K9VHWJuBInQTNBEfWqhw        5        5
# 6    xR4dihmHeOQ4v9DjNtAWyQ        4        5
# 7    drzW920Yf74ydnfVVVThkw        4        3
# 8    YMgZqBUAddmFErxLtCfK_w        5        4
# 9    BlN159yMZqj5fTfNRjdang        4        2
# 10   47w3jjQXCFYgEpYVRXbPwQ        4        4
# 11   Dav5aXAklIoiWQTA3wmfJw        5        4
# 12   mm2TaZpwjNobNV9oYYFVFA        5        5
# 13   9JUFYOFD3bylVVnm043W8A        4        4
# 14   8pLFYhWKzILEIYSl5qE-3w        5        2
# 15   YC9spir57ky1YkpjrQXokA        3        4
# 16   1z_8Tg0-fBGimNevXE2-0A        5        2
# 17   9gK7Qxqmbkgf_-na_nfQ9w        5        5
# 18   ZY2AZSd4lpA2iLaBcQXitA        5        5
# ...

# %%
dif = []
for i,rows in df.iterrows():
    dif.append(df['bus1_rat'][i]-df['bus2_rat'][i])

# %%
df['difference'] = dif

# %%
dif = []
for i,rows in df.iterrows():
    if df['bus1_rat'][i] == 1:
# Out:
#                        user bus1_rat bus2_rat  difference
# 0    JXHrhT72U6sZJQSkFfNzjw        3        5          -2
# 1    XrdEvB5ZuMwZN9J4aI55FA        5        3           2
# 2    6YYpJ59jfFCUHkGOpu2NTA        5        5           0
# 3    RKfETgoe0wuZds8EMDBw0Q        4        4           0
# 4    2Yg3D3xUNNzmn-SicXZOnA        4        5          -1
# 5    C1K9VHWJuBInQTNBEfWqhw        5        5           0
# 6    xR4dihmHeOQ4v9DjNtAWyQ        4        5          -1
# 7    drzW920Yf74ydnfVVVThkw        4        3           1
# 8    YMgZqBUAddmFErxLtCfK_w        5        4           1
# 9    BlN159yMZqj5fTfNRjdang        4        2           2
# 10   47w3jjQXCFYgEpYVRXbPwQ        4        4           0
# 11   Dav5aXAklIoiWQTA3wmfJw        5        4           1
# 12   mm2TaZpwjNobNV9oYYFVFA        5        5           0
# 13   9JUFYOFD3bylVVnm043W8A        4        4           0
# 14   8pLFYhWKzILEIYSl5qE-3w        5        2           3
# ...

# %%
same_user123 = []
rows_bus123 = set()
array_bus2 = np.array(bus2['user_id'])
array_bus3 = np.array(bus3['user_id'])
for i,rows in bus1.iterrows():
    if bus1['user_id'][i] in array_bus2:
        if bus1['user_id'][i] in array_bus3:
            same_user123.append(bus1['user_id'][i])
            rows_bus123.add(i)

# %%
df123 = pd.DataFrame(columns=["user", "bus1_rat", "bus2_rat","bus3_rat"])
for item in same_user123:
    star1 = bus1.loc[bus1['user_id'].isin([item])]['stars'].iloc[0]
    star2 = bus2.loc[bus2['user_id'].isin([item])]['stars'].iloc[0]
    star3 = bus3.loc[bus3['user_id'].isin([item])]['stars'].iloc[0]
    df123 = df123.append({"user":item,"bus1_rat":star1,"bus2_rat":star2,"bus3_rat":star3},ignore_index = True)

# %%
df123
# Out:
#                        user bus1_rat bus2_rat bus3_rat
# 0    6YYpJ59jfFCUHkGOpu2NTA        5        5        4
# 1    RKfETgoe0wuZds8EMDBw0Q        4        4        4
# 2    2Yg3D3xUNNzmn-SicXZOnA        4        5        4
# 3    C1K9VHWJuBInQTNBEfWqhw        5        5        5
# 4    BlN159yMZqj5fTfNRjdang        4        2        2
# 5    8pLFYhWKzILEIYSl5qE-3w        5        2        3
# 6    6jP47-9ykZ4eXIx88t16Ag        5        5        5
# 7    G-k3kIaf5cCIVhlHPx1Lsg        3        5        2
# 8    JjDQj-lLr-QCL9PQZ3FMcw        5        1        5
# 9    41HLwXnR0Lm3NUp01cIOQg        3        4        4
# 10   n86B7IkbU20AkxlFX_5aew        4        4        3
# 11   w9WmBotuUdQlmuLa3XUkFQ        5        5        4
# 12   cRbjLimgD-F0mRnO2Kp9sg        4        5        3
# 13   K5UHLEadijlcXeT1NQ0V4g        4        4        4
# 14   ol4WxweKYfn2ncAXHrFh6g        5        5        5
# 15   oEvsA_IvL0yRyI7d4lT-IA        3        4        3
# ...

# %%
print(df123.describe())
# Out:
#                           user  bus1_rat  bus2_rat  bus3_rat
# count                      177       177       177       177
# unique                     177         5         5         5
# top     Qb8sDTzr54wRtT9hm1ZBCg         4         5         4
# freq                         1        69        67        70

# %%
df123.plot(kind='box', subplots=True, layout=(2,2), sharex=False, sharey=False)
plt.show()

# %%
df.plot.hist('bus1_rat')

# %%
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
from sklearn import model_selection
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVC

# %%
data = df123.drop('user', 1);

# %%
data.tail(4)
# Out:
#     bus1_rat bus2_rat bus3_rat
# 173        3        4        5
# 174        4        4        4
# 175        4        3        3
# 176        2        5        1

# %%
array  = data.values

# %%
X = array[:,0:1]
Y = array[:,2]
validation_size = 0.20
seed = 7
X_train, X_validation, Y_train, Y_validation = model_selection.train_test_split(X, Y, test_size=validation_size, random_state=seed)

# %%
plt.hist(data)
# Out:
# ([array([ 1.,  0.,  6.,  0.,  0., 39.,  0., 69.,  0., 62.]),
#   array([ 6.,  0., 14.,  0.,  0., 23.,  0., 67.,  0., 67.]),
#   array([ 6.,  0., 15.,  0.,  0., 45.,  0., 70.,  0., 41.])],
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ]),
#  <a list of 3 Lists of Patches objects>)

# %%
plt.hist(data)
# Out:
# ([array([ 1.,  0.,  6.,  0.,  0., 39.,  0., 69.,  0., 62.]),
#   array([ 6.,  0., 14.,  0.,  0., 23.,  0., 67.,  0., 67.]),
#   array([ 6.,  0., 15.,  0.,  0., 45.,  0., 70.,  0., 41.])],
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ]),
#  <a list of 3 Lists of Patches objects>)

# %%
score_11 = 0
count11 = 0
score_12 = 0
count12 = 0
score_13 = 0
count13 = 0
score_14 = 0
count14 = 0
score_15 = 0
count15 = 0
score_21 = 0
count21 = 0
score_22 = 0
count22 = 0
score_23 = 0
count23 = 0
score_24 = 0
count24 = 0
score_25 = 0
count25 = 0
for i,rows in df123.iterrows():
    if df123['bus1_rat'][i] == 1:
        score_11 += df123['bus3_rat'][i]
        count11 += 1
    if df123['bus1_rat'][i] == 2:
        score_12 += df123['bus3_rat'][i]
        count12 += 1
    if df123['bus1_rat'][i] == 3:
        score_13 += df123['bus3_rat'][i]
        count13 += 1
    if df123['bus1_rat'][i] == 4:
        score_14 += df123['bus3_rat'][i]
        count14 += 1
    if df123['bus1_rat'][i] == 5:
        score_15 += df123['bus3_rat'][i]
        count15 += 1
    if df123['bus2_rat'][i] == 1:
        score_21 += df123['bus3_rat'][i]
        count21 += 1
    if df123['bus2_rat'][i] == 2:
        score_22 += df123['bus3_rat'][i]
        count22 += 1
    if df123['bus2_rat'][i] == 3:
        score_23 += df123['bus3_rat'][i]
        count23 += 1
    if df123['bus2_rat'][i] == 4:
        score_24 += df123['bus3_rat'][i]
        count24 += 1
    if df123['bus2_rat'][i] == 5:
        score_25 += df123['bus3_rat'][i]
        count25 += 1
        
avg11 = score_11/count11
avg12 = score_12/count12
avg13 = score_13/count13
avg14 = score_14/count14
avg15 = score_15/count15
avg21 = score_21/count21
avg22 = score_22/count22
avg23 = score_23/count23
avg24 = score_24/count24
avg25 = score_25/count25

# %%
count11+count12+count13+count14+count15
# Out:
# 177

# %%
plt.scatter(data['bus1_rat'],data['bus3_rat'],s=70, alpha=0.1)

# %%
plt.figure(figsize=(10,10))
plt.scatter(data['bus2_rat'],data['bus3_rat'],s=70, alpha=0.1)

# %%
prediction13 = [avg11,avg12,avg13,avg14,avg15]

# %%
prediction23 = [avg21,avg22,avg23,avg24,avg25]
x_axis = [1,2,3,4,5]

# %%
fig1 = plt.figure(figsize=(10,10))
plt.scatter(data['bus1_rat'],data['bus3_rat'],s=70, alpha=0.04, color='b', label='Restaurant data 1')
plt.scatter(x_axis,prediction13,color='g',s=70,label='Prediction data 1' )
plt.xlabel('Rating for First Restaurant', fontsize=16)
plt.ylabel('Rating for New Restaurant', fontsize=16)
plt.legend(prop={'size': 15})
plt.show()

fig2 = plt.figure(figsize=(10,10))
plt.scatter(data['bus2_rat'],data['bus3_rat'],s=70, alpha=0.01, color='r',label='Restaurant data 2')
plt.scatter(x_axis,prediction23,color='g',s=70,label='Prediction data 2')
plt.xlabel('Rating for First Restaurant', fontsize=16)
plt.ylabel('Rating for New Restaurant', fontsize=16)
plt.legend(prop={'size': 15})
plt.show()

# %%
fig3 = plt.subplot(1,1,1)
plt.scatter(data['bus1_rat'],data['bus3_rat'],s=70, alpha=0.04, color='b', label='Restaurant data 1')
plt.scatter(x_axis,prediction13,color='g',s=70,label='Prediction data 1' )
plt.xlabel('Rating for First Restaurant', fontsize=16)
plt.ylabel('Rating for New Restaurant', fontsize=16)
plt.legend(prop={'size': 15})
plt.show()

plt.subplot(1,1,1)
plt.scatter(data['bus2_rat'],data['bus3_rat'],s=70, alpha=0.01, color='r',label='Restaurant data 2')
plt.scatter(x_axis,prediction23,color='g',s=70,label='Prediction data 2')
plt.xlabel('Rating for First Restaurant', fontsize=16)
plt.ylabel('Rating for New Restaurant', fontsize=16)
plt.legend(prop={'size': 15})
plt.show()

# %%
pred_avg = []
for i,row in df123.iterrows():
    a = row[1] - 1
    b = row[2] -1 
    better = 0.5*(prediction13[a] + prediction23[b])
    pred_avg.append(better)

# %%
df123['predict'] = pred_avg

# %%
rat3 = []
pred3 = []
err = []
for i,row in df123.iterrows():
    rat3.append(df123['bus3_rat'][i])
    pred3.append(df123['predict'][i])
    error = df123['bus3_rat'][i] - df123['predict'][i]
    err.append(error)

# %%
err
# Out:
# [0.16213288396726044,
#  0.4129353233830848,
#  0.2562189054726369,
#  1.1621328839672604,
#  -1.5476190476190474,
#  -0.6417050691244239,
#  1.1621328839672604,
#  -1.7566016073478758,
#  0.82258064516129,
#  0.4001148105625716,
#  -0.5870646766169152,
#  0.16213288396726044,
#  -0.7437810945273631,
#  0.4129353233830848,
#  1.1621328839672604,
#  -0.5998851894374284,
#  1.3188493018777079,
#  -0.8839410939691446,
#  -0.7437810945273631,
#  -2.681150698122292,
#  0.11605890603085545,
#  0.3188493018777079,
#  -0.7566016073478758,
#  1.256218905472637,
#  0.16213288396726044,
#  0.3188493018777079,
#  0.16666666666666696,
#  -0.7437810945273631,
#  -1.5870646766169152,
#  -2.5998851894374284,
#  0.9038461538461533,
#  1.1621328839672604,
#  0.4129353233830848,
#  -0.8378671160327396,
#  0.2562189054726369,
#  0.3188493018777079,
#  -2.681150698122292,
#  1.4129353233830848,
#  0.3188493018777079,
#  -0.8378671160327396,
#  -0.6811506981222921,
#  0.4395604395604398,
# ...

# %%
fig5 = plt.figure(figsize=(10,10))
plt.hist(err,color = 'r')
plt.xlabel('Difference between predicted and given rating', fontsize=16)
plt.title('Histogram of error in prediction', fontsize=16)
# Out:
# Text(0.5,1,'Histogram of error in prediction')
